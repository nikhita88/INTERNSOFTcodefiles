# %%
import os
import time
import subprocess
import json
import requests
import wolframalpha
import webbrowser
import wikipedia
import datetime
import nest_asyncio
nest_asyncio.apply()

# %%
import speech_recognition as sr

import pyttsx3

# %%
print('LOADING YOUR AI PERSONAL ASSISTANT JARVIS')
# Out:
# LOADING YOUR AI PERSONAL ASSISTANT JARVIS

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty("voice", voices[0].id)

# %%
def speak(text):
    engine.say(text)
    engine.runAndWait()

# %%
def wishMe():
    hour = datetime.datetime.now().hour
    if hour >= 0 and hour < 12:
        speak("hey nb good morning")
        
    elif hour >= 12 and hour <= 18:
        speak("good afternoon nb")
    
    else:
        speak("it is already the night time better go to sleep")

# %%
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("i am listening")
        r.threshold = 1

        try:
             audio =r.listen(source, timeout = 5, phrase_time_limit=5)
        except:
            return "none"
            
       

        try:
            statement = r.recognize_google(audio, language='en-in')
            print(f"user said:{statement}\n")

        except Exception as e:
   
            return "none"
            
        return statement

# %%
speak("loading your personal AI assistant")
wishMe()

# %%
if __name__ == "__main__":
    speak("loading your personal AI assistant")
    wishMe()
    while True:
        speak("how can i help you")
        statement = takeCommand().lower()
        if statement == "none":
            continue
        if "goodbye" in statement or "bye" in  statement or "stop" in statement:
             speak("your personal AI assistant Jarvis is shutting down, good bye")
             print("your personal AI assistant Jarvis is shutting down, good bye")
             break
        elif "wikipedia" in statement:
            speak("searching wikipeddia")
            
            statement = statement.replace("wikipedia", " ")
            try:
                 results = wikipedia.summary(statement, sentences = 3)
                 speak("according to wikipedia")
                 print(results)
                 speak(results)
            except:
                speak("sorry could not find")
                
            results = wikipedia.summary(statement, sentences = 3)
            speak("according to wikipedia")
            print(results)
            speak(results)
        elif "open youtube" in statement:
            webbrowser.open_new_tab("https://www.youtube.com")
            speak("youtube is open for you")
            time.sleep(5)
        elif "open google" in statement:
            webbrowser.open_new_tab("https//www.google.com")
            speak("google search is open for you")
            time.sleep(5)

        elif "open gmail" in statement:
            webbrowser.open_new_tab("gmail.com")
            speak("your gmail is now open")
            time.sleep(5)
       
               
       
        elif "time" in statement or "what time" in statement:
            import datetime
            current_time = datetime.datetime.now().strftime("%H:%M:%S")
            speak("the current time is" + current_time)
            
      
        elif "open stack overflow" in statement:
            webbrowser.open_new_tab("https://stackoverflow.com/login")
            time.sleep(5)
            
        elif "news" in statement:
            news = webbrowser.open_new_tab("https://timesofindia.indiatimes.com/home/headlines")
            speak("here are some headlines for you from times of India")
            time.sleep(7)

        
                
        elif "search" in statement:
            statement = statement.replace("search", " ")
            webbrowser.open_new_tab(statement)
            time.sleep(5)
       
        elif "off" in statement or "out" in statement:
            speak("ok, your PC is shutting down in few seconds")
            subprocess.call(["shutdown", "/s", "/t", "1"])

time.sleep(3)
# Out:
# i am listening
# i am listening
# i am listening
# i am listening
# i am listening
# user said:goodbye
#
# your personal AI assistant Jarvis is shutting down, good bye
