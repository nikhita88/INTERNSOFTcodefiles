# %%
'hola'
# Out:
# 'hola'

# %%
'this is to welcome you'
# Out:
# 'this is to welcome you'

# %%
len('hey & wassup')
# Out:
# 12

# %%
levels = ('1', '2', '3',' 4', '5')
levels
# Out:
# ('1', '2', '3', ' 4', '5')

# %%
levels[0]
# Out:
# '1'

# %%
levels[0:]
# Out:
# ('1', '2', '3', ' 4', '5')

# %%
levels[:2]
# Out:
# ('1', '2')

# %%
levels[-1]
# Out:
# '5'

# %%
levels[:-1]
# Out:
# ('1', '2', '3', ' 4')

# %%
levels[::2]
# Out:
# ('1', '3', '5')

# %%
levels[::-1]
# Out:
# ('5', ' 4', '3', '2', '1')

# %%
str(levels) + 'all levels'
# Out:
# "('1', '2', '3', ' 4', '5')all levels"

# %%
levels = str(levels) + 'all levels'
levels
# Out:
# "('1', '2', '3', ' 4', '5')all levels"

# %%
repetition = 'nb'
repetition * 10
# Out:
# 'nbnbnbnbnbnbnbnbnbnb'

# %%
s = 'i am a string'

# %%
s.upper()
# Out:
# 'I AM A STRING'

# %%
s.split()
# Out:
# ['i', 'am', 'a', 'string']

# %%
s.split('i')
# Out:
# ['', ' am a str', 'ng']

# %%
# .format()
'you need to be here -> {}'.format({'before evening'})
# Out:
# "you need to be here -> {'before evening'}"

# %%
print(s)
# Out:
# i am a string

# %%
s.count('g')
# Out:
# 1

# %%
s.find('g')
# Out:
# 12

# %%
s.center(20, '!')
# Out:
# '!!!i am a string!!!!'

# %%
'hey\tman'.expandtabs()
# Out:
# 'hey     man'

# %%
'hey\tman'.expandtabs(2)
# Out:
# 'hey man'

# %%
s.isalnum()
# Out:
# False

# %%
s.islower()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s.endswith('a')
# Out:
# False

# %%
s.partition('a')
# Out:
# ('i ', 'a', 'm a string')

# %%
my_list = [1, 2, 3]

# %%
my_list = ['hello', 123, 'mic testing']
my_list
# Out:
# ['hello', 123, 'mic testing']

# %%
len(my_list)
# Out:
# 3

# %%
my_list[0]
# Out:
# 'hello'

# %%
my_list[1:]
# Out:
# [123, 'mic testing']

# %%
my_list[:2]
# Out:
# ['hello', 123]

# %%
my_list + ['yes']
# Out:
# ['hello', 123, 'mic testing', 'yes']

# %%
my_list
# Out:
# ['hello', 123, 'mic testing']

# %%
my_list = my_list + ['alright']

# %%
my_list
# Out:
# ['hello', 123, 'mic testing', 'alright']

# %%
my_list * 2
# Out:
# ['hello',
#  123,
#  'mic testing',
#  'alright',
#  'hello',
#  123,
#  'mic testing',
#  'alright']

# %%
my_list * 2
print(my_list *2, end = '')
# Out:
# ['hello', 123, 'mic testing', 'alright', 'hello', 123, 'mic testing', 'alright']

# %%
L = [100, 200, 300]

# %%
L.append(200)
L
# Out:
# [100, 200, 300, 200]

# %%
L.pop(1)
# Out:
# 200

# %%
item = L.pop()
item
# Out:
# 200

# %%
another_list = ['hi', 'hello', '1234']
print(another_list)
# Out:
# ['hi', 'hello', '1234']

# %%
another_list.reverse()
another_list
# Out:
# ['1234', 'hello', 'hi']

# %%
another_list.sort()
another_list
# Out:
# ['1234', 'hello', 'hi']

# %%
#nesting
l1 = [89, 99, 10]
l2 = [11, 22, 33]
l3 = [2, 4, 6]

all_l = [l1, l2, l3]
all_l
# Out:
# [[89, 99, 10], [11, 22, 33], [2, 4, 6]]

# %%
all_l[0]
# Out:
# [89, 99, 10]

# %%
all_l[0][0]
# Out:
# 89

# %%
all_l[0][2]
# Out:
# 10

# %%
#list comprehensions
first_col = [row[0] for row in all_l]

# %%
first_col
# Out:
# [89, 11, 2]

# %%
sec_col = [row[1] for row in all_l]

# %%
sec_col
# Out:
# [99, 22, 4]

# %%
third_col = [row[2] for row in all_l]

# %%
third_col
# Out:
# [10, 33, 6]

# %%
print(first_col, sec_col, third_col)
# Out:
# [89, 11, 2] [99, 22, 4] [10, 33, 6]

# %%
Alist = [888, 999, 222]

# %%
Alist
# Out:
# [888, 999, 222]

# %%
Alist.append(666)
Alist
# Out:
# [888, 999, 222, 666]

# %%
Alist.count(222)
# Out:
# 1

# %%
A_list = [10, 20, 30]
A_list.append([45, 55])
A_list
# Out:
# [10, 20, 30, [45, 55]]

# %%
A_list = [10, 20, 30]
A_list.extend([45, 55])
A_list
# Out:
# [10, 20, 30, 45, 55]

# %%
Alist
# Out:
# [888, 999, 222, 666]

# %%
Alist.insert(2, 'inserted')
Alist
# Out:
# [888, 999, 'inserted', 222, 666]

# %%
popped = Alist.pop()

# %%
popped
# Out:
# 666

# %%
Alist.remove(222)
Alist
# Out:
# [888, 999, 'inserted']

# %%
Alist.reverse()

# %%
Alist
# Out:
# ['inserted', 999, 888]
